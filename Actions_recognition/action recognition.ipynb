# %%
import torch
import torch.nn as nn

class NeuralNet(nn.Module):
    def __init__(
        self,
        input_size = 24,
        hidden_size = 256,
        num_classes = 3
    ):
        super(NeuralNet, self).__init__()
        self.l1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.l2 = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out)
        return out

class KeypointClassification:
    def __init__(self, path_model):
        self.path_model = path_model
        self.classes = ['run', 'stand', 'walk']
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.load_model()

    def load_model(self):
        self.model = NeuralNet()
        self.model.load_state_dict(
            torch.load(self.path_model, map_location=self.device)
        )
    def __call__(self, input_keypoint):
        if not type(input_keypoint) == torch.Tensor:
            input_keypoint = torch.tensor(
                input_keypoint, dtype=torch.float32
            )
        out = self.model(input_keypoint)
        _, predict = torch.max(out, -1)
        label_predict = self.classes[predict]
        return label_predict

if __name__ == '__main__':
    keypoint_classification = KeypointClassification(
        path_model='action_classification.pt'
    )

# %% [markdown]
# # Yolo_Model for key point extraction

# %%
import sys
import cv2
import numpy as np
from pydantic import BaseModel
import ultralytics

# Define keypoint mappings
class GetKeypoint(BaseModel):
    NOSE:           int = 0
    LEFT_EYE:       int = 1
    RIGHT_EYE:      int = 2
    LEFT_EAR:       int = 3
    RIGHT_EAR:      int = 4
    LEFT_SHOULDER:  int = 5
    RIGHT_SHOULDER: int = 6
    LEFT_ELBOW:     int = 7
    RIGHT_ELBOW:    int = 8
    LEFT_WRIST:     int = 9
    RIGHT_WRIST:    int = 10
    LEFT_HIP:       int = 11
    RIGHT_HIP:      int = 12
    LEFT_KNEE:      int = 13
    RIGHT_KNEE:     int = 14
    LEFT_ANKLE:     int = 15
    RIGHT_ANKLE:    int = 16

class DetectKeypoint:
    def __init__(self, yolov8_model='yolov8m-pose'):
        self.yolov8_model = yolov8_model
        self.get_keypoint = GetKeypoint()
        self.__load_model()

    def __load_model(self):
        if not self.yolov8_model.endswith('-pose'):
            sys.exit('Model not a YOLOv8 pose model')
        self.model = ultralytics.YOLO(self.yolov8_model)

    def extract_keypoint(self, keypoint: np.ndarray) -> list:
        return [
            keypoint[self.get_keypoint.NOSE][0], keypoint[self.get_keypoint.NOSE][1],
            keypoint[self.get_keypoint.LEFT_EYE][0], keypoint[self.get_keypoint.LEFT_EYE][1],
            keypoint[self.get_keypoint.RIGHT_EYE][0], keypoint[self.get_keypoint.RIGHT_EYE][1],
            keypoint[self.get_keypoint.LEFT_EAR][0], keypoint[self.get_keypoint.LEFT_EAR][1],
            keypoint[self.get_keypoint.RIGHT_EAR][0], keypoint[self.get_keypoint.RIGHT_EAR][1],
            keypoint[self.get_keypoint.LEFT_SHOULDER][0], keypoint[self.get_keypoint.LEFT_SHOULDER][1],
            keypoint[self.get_keypoint.RIGHT_SHOULDER][0], keypoint[self.get_keypoint.RIGHT_SHOULDER][1],
            keypoint[self.get_keypoint.LEFT_ELBOW][0], keypoint[self.get_keypoint.LEFT_ELBOW][1],
            keypoint[self.get_keypoint.RIGHT_ELBOW][0], keypoint[self.get_keypoint.RIGHT_ELBOW][1],
            keypoint[self.get_keypoint.LEFT_WRIST][0], keypoint[self.get_keypoint.LEFT_WRIST][1],
            keypoint[self.get_keypoint.RIGHT_WRIST][0], keypoint[self.get_keypoint.RIGHT_WRIST][1],
            keypoint[self.get_keypoint.LEFT_HIP][0], keypoint[self.get_keypoint.LEFT_HIP][1],
            keypoint[self.get_keypoint.RIGHT_HIP][0], keypoint[self.get_keypoint.RIGHT_HIP][1],
            keypoint[self.get_keypoint.LEFT_KNEE][0], keypoint[self.get_keypoint.LEFT_KNEE][1],
            keypoint[self.get_keypoint.RIGHT_KNEE][0], keypoint[self.get_keypoint.RIGHT_KNEE][1],
            keypoint[self.get_keypoint.LEFT_ANKLE][0], keypoint[self.get_keypoint.LEFT_ANKLE][1],
            keypoint[self.get_keypoint.RIGHT_ANKLE][0], keypoint[self.get_keypoint.RIGHT_ANKLE][1]
        ]

    def get_xy_keypoint(self, results) -> list:
        result_keypoint = results.keypoints.xyn[0].cpu().numpy()  # Access keypoints
        return self.extract_keypoint(result_keypoint)

    def __call__(self, image: np.ndarray):
        results = self.model(image, save=False)[0]  # Predict without saving
        return results

# %%
def extract_keypoint(keypoint):
    # List to hold the x, y coordinates of each keypoint
    keypoint_coordinates = []

    # Iterate over all keypoints defined in GetKeypoint
    for point in GetKeypoint.__fields__.values():
        x, y = keypoint[point.default]  # Access each keypoint's x, y coordinates
        keypoint_coordinates.extend([x, y])

    return keypoint_coordinates

# %%
import torch
import cv2
import numpy as np
from PIL import Image
import ultralytics

# Initialize the keypoint detection and classification models
detection_keypoint = DetectKeypoint()
classification_keypoint = KeypointClassification('action_classification.pt')

# Start capturing video from the webcam
cap = cv2.VideoCapture(0)

while True:
    # Read a frame from the webcam
    ret, frame = cap.read()
    if not ret:
        break

    # Perform keypoint detection
    results = detection_keypoint(frame)
    
    # Check if keypoints or bounding box are detected
    if results.keypoints is None or len(results.boxes) == 0:
        # Display message if no person or keypoints are detected
        cv2.putText(frame, "No person detected", (50, 50), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        cv2.imshow('Action Detection with Keypoints', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        continue

    # Extract keypoints for classification
    results_keypoint = detection_keypoint.get_xy_keypoint(results)
    input_classification = results_keypoint[10:]  # Selecting keypoints subset for classification
    results_classification = classification_keypoint(input_classification)

    # Get bounding box coordinates
    x_min, y_min, x_max, y_max = results.boxes.xyxy[0].cpu().numpy()

    # Draw bounding box and classification result on the frame
    frame = cv2.rectangle(frame, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 0, 255), 2)
    cv2.putText(frame, results_classification.upper(), (int(x_min), int(y_min) - 10), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    # Draw keypoints
    keypoints = results.keypoints.data[0].cpu().numpy()  # [0] to select the first set of keypoints if there's only one person
    
    # Iterate over each keypoint
    for keypoint in keypoints:
        x, y, confidence = keypoint
        if confidence > 0.5:  # Draw only keypoints with confidence > 0.5
            cv2.circle(frame, (int(x), int(y)), 5, (0, 255, 0), -1)  # Draw green keypoints
    
    # Define keypoint connections (specific indices may vary depending on your keypoint model)
    connections = [
        (5, 6), (5, 11), (6, 12), (11, 13), (13, 15), (12, 14), (14, 16)
    ]
    for (start, end) in connections:
        if start < len(keypoints) and end < len(keypoints):  # Ensure indices are within bounds
            x_start, y_start, conf_start = keypoints[start]
            x_end, y_end, conf_end = keypoints[end]
            # Draw line if both points have high confidence
            if conf_start > 0.5 and conf_end > 0.5:
                cv2.line(frame, (int(x_start), int(y_start)), (int(x_end), int(y_end)), (255, 0, 0), 2)

    # Display the frame with the bounding box, keypoints, and classification
    cv2.imshow('Action Detection with Keypoints', frame)

    # Break loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 986.1ms
# Speed: 44.7ms preprocess, 986.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1031.0ms
# Speed: 12.6ms preprocess, 1031.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 952.3ms
# Speed: 6.1ms preprocess, 952.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1076.6ms
# Speed: 28.5ms preprocess, 1076.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1055.5ms
# Speed: 7.0ms preprocess, 1055.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 959.2ms
# Speed: 6.6ms preprocess, 959.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 936.1ms
# Speed: 6.3ms preprocess, 936.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 932.6ms
# Speed: 4.1ms preprocess, 932.6ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 928.5ms
# Speed: 4.4ms preprocess, 928.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 919.0ms
# Speed: 8.0ms preprocess, 919.0ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 929.4ms
# Speed: 5.4ms preprocess, 929.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 924.3ms
# Speed: 5.6ms preprocess, 924.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 931.0ms
# Speed: 4.0ms preprocess, 931.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 963.2ms
# Speed: 3.7ms preprocess, 963.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 927.5ms
# Speed: 4.2ms preprocess, 927.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 942.1ms
# Speed: 3.2ms preprocess, 942.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 924.7ms
# Speed: 6.7ms preprocess, 924.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 932.9ms
# Speed: 4.1ms preprocess, 932.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 932.2ms
# Speed: 4.0ms preprocess, 932.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 940.6ms
# Speed: 3.9ms preprocess, 940.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 933.3ms
# Speed: 4.1ms preprocess, 933.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 921.7ms
# Speed: 4.9ms preprocess, 921.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1066.2ms
# Speed: 3.7ms preprocess, 1066.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 927.6ms
# Speed: 4.3ms preprocess, 927.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 951.6ms
# Speed: 4.0ms preprocess, 951.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 914.8ms
# Speed: 5.7ms preprocess, 914.8ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 938.4ms
# Speed: 3.8ms preprocess, 938.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 931.9ms
# Speed: 4.1ms preprocess, 931.9ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 939.5ms
# Speed: 4.1ms preprocess, 939.5ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 918.9ms
# Speed: 3.7ms preprocess, 918.9ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 927.4ms
# Speed: 4.8ms preprocess, 927.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 950.8ms
# Speed: 4.2ms preprocess, 950.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 942.7ms
# Speed: 4.0ms preprocess, 942.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 926.0ms
# Speed: 4.0ms preprocess, 926.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1008.6ms
# Speed: 4.3ms preprocess, 1008.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 962.3ms
# Speed: 4.2ms preprocess, 962.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 937.7ms
# Speed: 2.9ms preprocess, 937.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 910.3ms
# Speed: 3.4ms preprocess, 910.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 935.3ms
# Speed: 5.0ms preprocess, 935.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 936.1ms
# Speed: 13.7ms preprocess, 936.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 910.4ms
# Speed: 4.0ms preprocess, 910.4ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 918.1ms
# Speed: 4.1ms preprocess, 918.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 931.7ms
# Speed: 4.0ms preprocess, 931.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 913.1ms
# Speed: 3.4ms preprocess, 913.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 928.2ms
# Speed: 4.4ms preprocess, 928.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 945.2ms
# Speed: 4.0ms preprocess, 945.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 920.4ms
# Speed: 4.9ms preprocess, 920.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 908.1ms
# Speed: 5.1ms preprocess, 908.1ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 928.7ms
# Speed: 4.9ms preprocess, 928.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1086.9ms
# Speed: 3.8ms preprocess, 1086.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 922.0ms
# Speed: 3.8ms preprocess, 922.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 921.4ms
# Speed: 4.1ms preprocess, 921.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 924.8ms
# Speed: 3.9ms preprocess, 924.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 923.1ms
# Speed: 0.0ms preprocess, 923.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 947.4ms
# Speed: 4.0ms preprocess, 947.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 975.5ms
# Speed: 4.0ms preprocess, 975.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 921.4ms
# Speed: 4.0ms preprocess, 921.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 915.1ms
# Speed: 4.0ms preprocess, 915.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 924.2ms
# Speed: 4.0ms preprocess, 924.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 927.6ms
# Speed: 4.0ms preprocess, 927.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 923.0ms
# Speed: 4.0ms preprocess, 923.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 922.8ms
# Speed: 4.0ms preprocess, 922.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 924.1ms
# Speed: 4.0ms preprocess, 924.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 910.5ms
# Speed: 5.7ms preprocess, 910.5ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 929.2ms
# Speed: 4.0ms preprocess, 929.2ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 917.0ms
# Speed: 4.3ms preprocess, 917.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 936.9ms
# Speed: 3.0ms preprocess, 936.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 912.6ms
# Speed: 4.0ms preprocess, 912.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 925.3ms
# Speed: 4.0ms preprocess, 925.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1064.5ms
# Speed: 4.0ms preprocess, 1064.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 917.5ms
# Speed: 4.5ms preprocess, 917.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 920.1ms
# Speed: 4.0ms preprocess, 920.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 909.7ms
# Speed: 4.0ms preprocess, 909.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 923.2ms
# Speed: 5.2ms preprocess, 923.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 948.0ms
# Speed: 4.0ms preprocess, 948.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1020.8ms
# Speed: 6.0ms preprocess, 1020.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 992.5ms
# Speed: 4.0ms preprocess, 992.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 959.1ms
# Speed: 4.4ms preprocess, 959.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 935.1ms
# Speed: 4.0ms preprocess, 935.1ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 959.9ms
# Speed: 4.0ms preprocess, 959.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1124.4ms
# Speed: 5.0ms preprocess, 1124.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1459.8ms
# Speed: 5.0ms preprocess, 1459.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1093.9ms
# Speed: 5.0ms preprocess, 1093.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 986.1ms
# Speed: 3.0ms preprocess, 986.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1246.6ms
# Speed: 3.4ms preprocess, 1246.6ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1052.1ms
# Speed: 6.1ms preprocess, 1052.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1003.0ms
# Speed: 4.0ms preprocess, 1003.0ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 978.1ms
# Speed: 4.3ms preprocess, 978.1ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1677.6ms
# Speed: 12.0ms preprocess, 1677.6ms inference, 10.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1132.2ms
# Speed: 9.1ms preprocess, 1132.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1004.0ms
# Speed: 4.0ms preprocess, 1004.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 997.0ms
# Speed: 4.0ms preprocess, 997.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 982.0ms
# Speed: 6.0ms preprocess, 982.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1035.0ms
# Speed: 6.0ms preprocess, 1035.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1072.0ms
# Speed: 4.0ms preprocess, 1072.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1136.0ms
# Speed: 6.0ms preprocess, 1136.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1054.0ms
# Speed: 3.0ms preprocess, 1054.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 993.0ms
# Speed: 5.0ms preprocess, 993.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1037.0ms
# Speed: 4.0ms preprocess, 1037.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1078.0ms
# Speed: 4.0ms preprocess, 1078.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1072.0ms
# Speed: 5.0ms preprocess, 1072.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1077.1ms
# Speed: 4.0ms preprocess, 1077.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1110.0ms
# Speed: 5.0ms preprocess, 1110.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1067.0ms
# Speed: 4.0ms preprocess, 1067.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1077.0ms
# Speed: 5.0ms preprocess, 1077.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 987.0ms
# Speed: 6.0ms preprocess, 987.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1159.0ms
# Speed: 4.0ms preprocess, 1159.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 965.0ms
# Speed: 4.0ms preprocess, 965.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 953.0ms
# Speed: 5.0ms preprocess, 953.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 956.0ms
# Speed: 4.0ms preprocess, 956.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1037.0ms
# Speed: 5.0ms preprocess, 1037.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1187.0ms
# Speed: 4.0ms preprocess, 1187.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1048.0ms
# Speed: 5.0ms preprocess, 1048.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1112.0ms
# Speed: 5.0ms preprocess, 1112.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1056.0ms
# Speed: 6.0ms preprocess, 1056.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1006.0ms
# Speed: 6.0ms preprocess, 1006.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 964.0ms
# Speed: 4.0ms preprocess, 964.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 931.0ms
# Speed: 4.0ms preprocess, 931.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 933.0ms
# Speed: 5.0ms preprocess, 933.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 923.0ms
# Speed: 4.0ms preprocess, 923.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 933.0ms
# Speed: 4.0ms preprocess, 933.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 929.0ms
# Speed: 6.0ms preprocess, 929.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 931.0ms
# Speed: 5.0ms preprocess, 931.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 930.0ms
# Speed: 4.0ms preprocess, 930.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1105.0ms
# Speed: 4.0ms preprocess, 1105.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 921.0ms
# Speed: 5.0ms preprocess, 921.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 931.0ms
# Speed: 5.0ms preprocess, 931.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 922.0ms
# Speed: 3.0ms preprocess, 922.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 936.0ms
# Speed: 4.0ms preprocess, 936.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 948.0ms
# Speed: 5.0ms preprocess, 948.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 949.0ms
# Speed: 4.0ms preprocess, 949.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 948.0ms
# Speed: 4.0ms preprocess, 948.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 924.0ms
# Speed: 4.0ms preprocess, 924.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 945.0ms
# Speed: 4.0ms preprocess, 945.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 927.0ms
# Speed: 3.0ms preprocess, 927.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 987.0ms
# Speed: 4.0ms preprocess, 987.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 971.0ms
# Speed: 3.0ms preprocess, 971.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 950.0ms
# Speed: 4.0ms preprocess, 950.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 965.0ms
# Speed: 4.0ms preprocess, 965.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 934.0ms
# Speed: 5.0ms preprocess, 934.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 926.0ms
# Speed: 4.0ms preprocess, 926.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 937.0ms
# Speed: 5.0ms preprocess, 937.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 931.0ms
# Speed: 4.0ms preprocess, 931.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1091.0ms
# Speed: 4.0ms preprocess, 1091.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 932.0ms
# Speed: 4.0ms preprocess, 932.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 951.0ms
# Speed: 4.0ms preprocess, 951.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 939.0ms
# Speed: 4.0ms preprocess, 939.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 922.0ms
# Speed: 4.0ms preprocess, 922.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 937.0ms
# Speed: 5.0ms preprocess, 937.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 934.0ms
# Speed: 4.0ms preprocess, 934.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 934.0ms
# Speed: 5.0ms preprocess, 934.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 929.0ms
# Speed: 4.0ms preprocess, 929.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 933.0ms
# Speed: 6.0ms preprocess, 933.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 938.0ms
# Speed: 4.0ms preprocess, 938.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 929.0ms
# Speed: 4.0ms preprocess, 929.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 935.0ms
# Speed: 4.0ms preprocess, 935.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 961.0ms
# Speed: 4.0ms preprocess, 961.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 936.0ms
# Speed: 4.0ms preprocess, 936.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 948.0ms
# Speed: 5.0ms preprocess, 948.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 957.0ms
# Speed: 4.0ms preprocess, 957.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1004.0ms
# Speed: 4.0ms preprocess, 1004.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1292.0ms
# Speed: 4.0ms preprocess, 1292.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 952.0ms
# Speed: 4.0ms preprocess, 952.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 914.0ms
# Speed: 6.0ms preprocess, 914.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 922.0ms
# Speed: 5.0ms preprocess, 922.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 918.0ms
# Speed: 4.0ms preprocess, 918.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 948.0ms
# Speed: 5.0ms preprocess, 948.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 923.0ms
# Speed: 4.0ms preprocess, 923.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 942.0ms
# Speed: 4.0ms preprocess, 942.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 919.0ms
# Speed: 4.0ms preprocess, 919.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 915.0ms
# Speed: 5.0ms preprocess, 915.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 949.0ms
# Speed: 5.0ms preprocess, 949.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 947.5ms
# Speed: 4.0ms preprocess, 947.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 941.0ms
# Speed: 4.0ms preprocess, 941.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 919.0ms
# Speed: 4.0ms preprocess, 919.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 929.0ms
# Speed: 4.0ms preprocess, 929.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 958.0ms
# Speed: 4.0ms preprocess, 958.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 925.0ms
# Speed: 4.0ms preprocess, 925.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 939.0ms
# Speed: 4.0ms preprocess, 939.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 939.0ms
# Speed: 6.0ms preprocess, 939.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 936.0ms
# Speed: 6.0ms preprocess, 936.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1113.0ms
# Speed: 4.0ms preprocess, 1113.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 979.0ms
# Speed: 5.0ms preprocess, 979.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1018.0ms
# Speed: 5.0ms preprocess, 1018.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 971.0ms
# Speed: 4.0ms preprocess, 971.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 956.0ms
# Speed: 3.0ms preprocess, 956.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 975.0ms
# Speed: 5.0ms preprocess, 975.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1001.0ms
# Speed: 11.0ms preprocess, 1001.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1045.0ms
# Speed: 4.0ms preprocess, 1045.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 968.0ms
# Speed: 4.0ms preprocess, 968.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 949.0ms
# Speed: 5.0ms preprocess, 949.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 934.1ms
# Speed: 4.0ms preprocess, 934.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 939.0ms
# Speed: 4.0ms preprocess, 939.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1024.0ms
# Speed: 4.0ms preprocess, 1024.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1694.0ms
# Speed: 5.0ms preprocess, 1694.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 978.0ms
# Speed: 4.0ms preprocess, 978.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1003.0ms
# Speed: 5.0ms preprocess, 1003.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 969.0ms
# Speed: 4.0ms preprocess, 969.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1138.0ms
# Speed: 5.0ms preprocess, 1138.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 970.0ms
# Speed: 4.0ms preprocess, 970.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 962.6ms
# Speed: 4.0ms preprocess, 962.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 967.0ms
# Speed: 6.0ms preprocess, 967.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 972.1ms
# Speed: 5.0ms preprocess, 972.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1011.1ms
# Speed: 4.0ms preprocess, 1011.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 980.0ms
# Speed: 4.0ms preprocess, 980.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 972.0ms
# Speed: 4.0ms preprocess, 972.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1004.0ms
# Speed: 5.0ms preprocess, 1004.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1050.0ms
# Speed: 10.0ms preprocess, 1050.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1035.5ms
# Speed: 4.0ms preprocess, 1035.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1361.0ms
# Speed: 7.0ms preprocess, 1361.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1078.0ms
# Speed: 4.0ms preprocess, 1078.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 979.0ms
# Speed: 4.0ms preprocess, 979.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 959.0ms
# Speed: 6.0ms preprocess, 959.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 952.0ms
# Speed: 4.0ms preprocess, 952.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 946.0ms
# Speed: 4.0ms preprocess, 946.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 968.0ms
# Speed: 4.0ms preprocess, 968.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 987.0ms
# Speed: 5.0ms preprocess, 987.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1126.0ms
# Speed: 4.0ms preprocess, 1126.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 965.0ms
# Speed: 6.0ms preprocess, 965.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1019.0ms
# Speed: 4.0ms preprocess, 1019.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 987.0ms
# Speed: 18.0ms preprocess, 987.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 929.0ms
# Speed: 4.0ms preprocess, 929.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 938.0ms
# Speed: 4.0ms preprocess, 938.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 941.0ms
# Speed: 4.0ms preprocess, 941.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 951.0ms
# Speed: 5.0ms preprocess, 951.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 971.0ms
# Speed: 4.0ms preprocess, 971.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1009.0ms
# Speed: 10.0ms preprocess, 1009.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 960.0ms
# Speed: 4.0ms preprocess, 960.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 927.0ms
# Speed: 3.0ms preprocess, 927.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 933.0ms
# Speed: 4.0ms preprocess, 933.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 953.0ms
# Speed: 4.0ms preprocess, 953.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1109.0ms
# Speed: 4.0ms preprocess, 1109.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 970.0ms
# Speed: 4.0ms preprocess, 970.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 945.0ms
# Speed: 4.0ms preprocess, 945.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 933.0ms
# Speed: 4.0ms preprocess, 933.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 934.0ms
# Speed: 4.0ms preprocess, 934.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1119.0ms
# Speed: 5.0ms preprocess, 1119.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 931.0ms
# Speed: 4.0ms preprocess, 931.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 921.0ms
# Speed: 4.0ms preprocess, 921.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 938.0ms
# Speed: 4.0ms preprocess, 938.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 932.0ms
# Speed: 3.0ms preprocess, 932.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 932.0ms
# Speed: 4.0ms preprocess, 932.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 931.0ms
# Speed: 4.0ms preprocess, 931.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 938.0ms
# Speed: 5.0ms preprocess, 938.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 930.0ms
# Speed: 4.0ms preprocess, 930.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 924.0ms
# Speed: 4.0ms preprocess, 924.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 927.0ms
# Speed: 4.0ms preprocess, 927.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 946.0ms
# Speed: 5.0ms preprocess, 946.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 946.0ms
# Speed: 4.0ms preprocess, 946.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 927.0ms
# Speed: 4.0ms preprocess, 927.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 930.0ms
# Speed: 4.0ms preprocess, 930.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 929.0ms
# Speed: 4.0ms preprocess, 929.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 943.0ms
# Speed: 4.0ms preprocess, 943.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 933.0ms
# Speed: 4.0ms preprocess, 933.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1095.0ms
# Speed: 4.0ms preprocess, 1095.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 926.0ms
# Speed: 4.0ms preprocess, 926.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 949.0ms
# Speed: 4.0ms preprocess, 949.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 958.0ms
# Speed: 4.0ms preprocess, 958.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 929.0ms
# Speed: 4.0ms preprocess, 929.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 990.0ms
# Speed: 3.0ms preprocess, 990.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 943.0ms
# Speed: 4.0ms preprocess, 943.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 935.0ms
# Speed: 4.0ms preprocess, 935.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 939.0ms
# Speed: 4.0ms preprocess, 939.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 934.0ms
# Speed: 4.0ms preprocess, 934.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 934.0ms
# Speed: 4.0ms preprocess, 934.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 917.5ms
# Speed: 4.0ms preprocess, 917.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 940.0ms
# Speed: 4.0ms preprocess, 940.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 920.5ms
# Speed: 4.0ms preprocess, 920.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 941.2ms
# Speed: 4.0ms preprocess, 941.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 936.0ms
# Speed: 4.0ms preprocess, 936.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 926.3ms
# Speed: 4.0ms preprocess, 926.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1267.1ms
# Speed: 5.0ms preprocess, 1267.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 931.0ms
# Speed: 4.0ms preprocess, 931.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 924.0ms
# Speed: 4.0ms preprocess, 924.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1043.0ms
# Speed: 6.0ms preprocess, 1043.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1119.3ms
# Speed: 4.0ms preprocess, 1119.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1068.1ms
# Speed: 6.0ms preprocess, 1068.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 979.0ms
# Speed: 7.0ms preprocess, 979.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 978.0ms
# Speed: 5.0ms preprocess, 978.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1288.0ms
# Speed: 5.0ms preprocess, 1288.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 944.0ms
# Speed: 4.0ms preprocess, 944.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1003.0ms
# Speed: 19.0ms preprocess, 1003.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 961.0ms
# Speed: 5.0ms preprocess, 961.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 909.0ms
# Speed: 5.0ms preprocess, 909.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 924.0ms
# Speed: 5.0ms preprocess, 924.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1008.0ms
# Speed: 5.0ms preprocess, 1008.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 942.0ms
# Speed: 4.0ms preprocess, 942.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1079.0ms
# Speed: 3.0ms preprocess, 1079.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 949.0ms
# Speed: 5.0ms preprocess, 949.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 906.0ms
# Speed: 5.0ms preprocess, 906.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 941.0ms
# Speed: 4.0ms preprocess, 941.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 918.0ms
# Speed: 4.0ms preprocess, 918.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 933.0ms
# Speed: 4.0ms preprocess, 933.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 929.0ms
# Speed: 5.0ms preprocess, 929.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 915.0ms
# Speed: 5.0ms preprocess, 915.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 914.0ms
# Speed: 5.0ms preprocess, 914.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 946.0ms
# Speed: 4.0ms preprocess, 946.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1003.0ms
# Speed: 4.0ms preprocess, 1003.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1015.0ms
# Speed: 4.0ms preprocess, 1015.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 954.0ms
# Speed: 4.0ms preprocess, 954.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 963.0ms
# Speed: 4.0ms preprocess, 963.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 971.0ms
# Speed: 4.0ms preprocess, 971.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1130.6ms
# Speed: 4.0ms preprocess, 1130.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1007.0ms
# Speed: 4.0ms preprocess, 1007.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 970.0ms
# Speed: 6.0ms preprocess, 970.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1055.0ms
# Speed: 9.0ms preprocess, 1055.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1041.0ms
# Speed: 5.0ms preprocess, 1041.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 977.0ms
# Speed: 4.0ms preprocess, 977.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 956.0ms
# Speed: 4.0ms preprocess, 956.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 960.0ms
# Speed: 4.0ms preprocess, 960.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 943.0ms
# Speed: 3.0ms preprocess, 943.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
